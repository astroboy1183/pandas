# %%
import pandas as pd

# %%
path=r'C:\Users\Jayanth.Appalla\Desktop\Sales details with delivery.xlsx'

# %%
sales_data=pd.read_excel(path,0) # first way of reading it.

# %%
sales_data
# Out:
#       Sales Organization  Distribution Channel  Division Sales Office  \
# 0                   1000                    30        19         ZUTA
# 1                   1000                    30        11         ZUTD
# 2                   1000                    30        11         ZUTD
# 3                   1000                    10        11         ZUTD
# 4                   1000                    10        11         ZUTM
# ...                  ...                   ...       ...          ...
# 3425                1000                    30        21         ZUPT
# 3426                1000                    30        21         ZUPT
# 3427                1000                    30        21         ZUTD
# 3428                1000                    30        21         ZUPT
# 3429                1000                    30        21         ZUTD
#
#       Sales Document  Item Sales document type Document Date    Delivery  \
# ...

# %%
xl_file=pd.ExcelFile(path) #2nd way of reading it. Read the entire workbook and then parse the sheet we want.

# %%
sales_data=xl_file.parse('Sheet1')

# %%
sales_data
# Out:
#       Sales Organization  Distribution Channel  Division Sales Office  \
# 0                   1000                    30        19         ZUTA
# 1                   1000                    30        11         ZUTD
# 2                   1000                    30        11         ZUTD
# 3                   1000                    10        11         ZUTD
# 4                   1000                    10        11         ZUTM
# ...                  ...                   ...       ...          ...
# 3425                1000                    30        21         ZUPT
# 3426                1000                    30        21         ZUPT
# 3427                1000                    30        21         ZUTD
# 3428                1000                    30        21         ZUPT
# 3429                1000                    30        21         ZUTD
#
#       Sales Document  Item Sales document type Document Date    Delivery  \
# ...

# %%
sales_data.shape
# Out:
# (3430, 76)

# %%
sales_data.isnull().sum()
# Out:
# Sales Organization         0
# Distribution Channel       0
# Division                   0
# Sales Office               0
# Sales Document             0
#                         ...
# Transporter Text          11
# Plant                      0
# Plant Name                 0
# Storage location        3430
# Storage Loc.Text        3430
# Length: 76, dtype: int64
